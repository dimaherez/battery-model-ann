# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from data import DataProvider
import typing as T
import numpy as np

# %%
provider = DataProvider()
raw_df = provider.read_excel()
scaled_df = provider.scale_data(raw_df)

# %%
charging_df_0_2 = provider.get_charging_data(scaled_df, 0, -2)
charging_df_2_8 = provider.get_charging_data(scaled_df, -2, -8)
charging_df_8_14 = provider.get_charging_data(scaled_df, -8, -14)

charging_dfs = [charging_df_0_2, charging_df_2_8, charging_df_8_14]
rangesStrings = ["0A - 2A", "2A - 8A", "8A - 14A"]

# %%
from StackingBenchmaker import StackingBenchmarker
from utils import predict_and_plot

ensemble_benchmarker = StackingBenchmarker()
results = ensemble_benchmarker.run_benchmark(charging_dfs, rangesStrings)
# Out:
# 🧱 Processing Range 1 (0A - 2A) with Stacking Ensemble...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 244
# [LightGBM] [Info] Number of data points in the train set: 4434, number of used features: 3
# [LightGBM] [Info] Start training from score 0.421456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000075 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 221
# [LightGBM] [Info] Number of data points in the train set: 3547, number of used features: 3
# [LightGBM] [Info] Start training from score 0.420113
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000026 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 226
# [LightGBM] [Info] Number of data points in the train set: 3547, number of used features: 3
# [LightGBM] [Info] Start training from score 0.422527
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 226
# [LightGBM] [Info] Number of data points in the train set: 3547, number of used features: 3
# [LightGBM] [Info] Start training from score 0.422558
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000025 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 224
# [LightGBM] [Info] Number of data points in the train set: 3547, number of used features: 3
# [LightGBM] [Info] Start training from score 0.422176
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000060 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 226
# [LightGBM] [Info] Number of data points in the train set: 3548, number of used features: 3
# [LightGBM] [Info] Start training from score 0.419903
#   ✅ Stacking Done. MAE: 0.3432 V | R²: 0.6983
#
# 🧱 Processing Range 2 (2A - 8A) with Stacking Ensemble...
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000070 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340
# [LightGBM] [Info] Number of data points in the train set: 1912, number of used features: 3
# [LightGBM] [Info] Start training from score 0.354668
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000076 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 339
# [LightGBM] [Info] Number of data points in the train set: 1529, number of used features: 3
# [LightGBM] [Info] Start training from score 0.353753
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341
# [LightGBM] [Info] Number of data points in the train set: 1529, number of used features: 3
# [LightGBM] [Info] Start training from score 0.355728
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 338
# [LightGBM] [Info] Number of data points in the train set: 1530, number of used features: 3
# [LightGBM] [Info] Start training from score 0.352029
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000053 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342
# [LightGBM] [Info] Number of data points in the train set: 1530, number of used features: 3
# [LightGBM] [Info] Start training from score 0.356596
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000039 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 343
# [LightGBM] [Info] Number of data points in the train set: 1530, number of used features: 3
# [LightGBM] [Info] Start training from score 0.355232
#   ✅ Stacking Done. MAE: 0.1794 V | R²: 0.7836
#
# 🧱 Processing Range 3 (8A - 14A) with Stacking Ensemble...
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000056 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1308, number of used features: 3
# [LightGBM] [Info] Start training from score 0.316363
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1046, number of used features: 3
# [LightGBM] [Info] Start training from score 0.316975
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000046 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335
# [LightGBM] [Info] Number of data points in the train set: 1046, number of used features: 3
# [LightGBM] [Info] Start training from score 0.317061
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 331
# [LightGBM] [Info] Number of data points in the train set: 1046, number of used features: 3
# [LightGBM] [Info] Start training from score 0.313199
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000047 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 333
# [LightGBM] [Info] Number of data points in the train set: 1047, number of used features: 3
# [LightGBM] [Info] Start training from score 0.315224
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000048 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1047, number of used features: 3
# [LightGBM] [Info] Start training from score 0.319355
#   ✅ Stacking Done. MAE: 0.1719 V | R²: 0.7459
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
for key, result in results.items():
    y_true = result['y_true'].flatten()
    y_pred = result['y_pred'].flatten()
    df_original = result["df_original"]

    print(f"\n--- Visualizing Best Model: {key} ---")
    print(f"  -> MAE of Model: {result["mae"]:.4f}")
    print(f"  -> MSE of Model: {result["mse"]:.6f}")
    print(f"  -> R2 of Model: {result["r2"]:.6f}")

    predict_and_plot(key, results, provider)
# Out:
# --- Visualizing Best Model: 0A - 2A ---
#   -> MAE of Model: 0.3432
#   -> MSE of Model: 0.243641
#   -> R2 of Model: 0.698294
#
# --- Metrics vs. Smoothed Baseline for '0A - 2A' ---
#   Smoothed MAE: 0.1530 V
#   Smoothed MSE: 0.0384
#   Smoothed R²:  0.8096
# -------------------------------------------------
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# --- Visualizing Best Model: 2A - 8A ---
#   -> MAE of Model: 0.1794
#   -> MSE of Model: 0.076769
#   -> R2 of Model: 0.783552
#
# --- Metrics vs. Smoothed Baseline for '2A - 8A' ---
#   Smoothed MAE: 0.0774 V
#   Smoothed MSE: 0.0111
#   Smoothed R²:  0.9400
# -------------------------------------------------
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# --- Visualizing Best Model: 8A - 14A ---
#   -> MAE of Model: 0.1719
#   -> MSE of Model: 0.087392
#   -> R2 of Model: 0.745884
#
# --- Metrics vs. Smoothed Baseline for '8A - 14A' ---
#   Smoothed MAE: 0.0475 V
#   Smoothed MSE: 0.0044
#   Smoothed R²:  0.9719
# -------------------------------------------------
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
