# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from data import DataProvider
import typing as T
import numpy as np

# %%
provider = DataProvider()
raw_df = provider.read_excel()
scaled_df = provider.scale_data(raw_df)

# %%
charging_df_1_3 = provider.get_charging_data(scaled_df, -1, -3)
charging_df_9_11 = provider.get_charging_data(scaled_df, -9, -11)
charging_df_19_21 = provider.get_charging_data(scaled_df, -19, -21)
charging_df_29_31 = provider.get_charging_data(scaled_df, -29, -31)
charging_dfs = [charging_df_1_3, charging_df_9_11, charging_df_19_21, charging_df_29_31]

discharging_df_1_3 = provider.get_discharging_data(scaled_df, 1, 3)
discharging_df_9_11 = provider.get_discharging_data(scaled_df, 9, 11)
discharging_df_19_21 = provider.get_discharging_data(scaled_df, 19, 21)
discharging_df_29_31 = provider.get_discharging_data(scaled_df, 29, 31)
discharging_dfs = [discharging_df_1_3, discharging_df_9_11, discharging_df_19_21, discharging_df_29_31]

rangesStrings = ["1A - 3A", "9A - 11A", "19A - 21A", "29A - 31A"]

# %%
from StackingBenchmaker import StackingBenchmarker
from utils import predict_and_plot

ensemble_benchmarker = StackingBenchmarker()
results = ensemble_benchmarker.run_benchmark(charging_dfs, rangesStrings)
# Out:
# 🧱 Processing Range 1 (1A - 3A) with Stacking Ensemble...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 228
# [LightGBM] [Info] Number of data points in the train set: 768, number of used features: 3
# [LightGBM] [Info] Start training from score 0.311045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
for key, result in results.items():
    y_true = result['y_true'].flatten()
    y_pred = result['y_pred'].flatten()
    df_original = result["df_original"]

    print(f"\n--- Visualizing Best Model: {key} ---")
    print(f"  -> MAE of Model: {result["mae"]:.4f}")
    print(f"  -> MSE of Model: {result["mse"]:.6f}")
    print(f"  -> R2 of Model: {result["r2"]:.6f}")

    predict_and_plot(key, results, provider)
# Out:
# --- Visualizing Best Model: 1A - 3A ---
#   -> MAE of Model: 0.2403
#   -> MSE of Model: 0.165802
#   -> R2 of Model: 0.673270
#
# --- Metrics vs. Smoothed Baseline for '1A - 3A' ---
#   Smoothed MAE: 0.0906 V
#   Smoothed MSE: 0.0182
#   Smoothed R²:  0.8934
# -------------------------------------------------
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# --- Visualizing Best Model: 9A - 11A ---
#   -> MAE of Model: 0.2309
#   -> MSE of Model: 0.162218
#   -> R2 of Model: 0.675469
#
# --- Metrics vs. Smoothed Baseline for '9A - 11A' ---
#   Smoothed MAE: 0.0738 V
#   Smoothed MSE: 0.0081
#   Smoothed R²:  0.9440
# -------------------------------------------------
# ...

# %%
results = ensemble_benchmarker.run_benchmark(discharging_dfs, rangesStrings)
# Out:
# 🧱 Processing Range 1 (1A - 3A) with Stacking Ensemble...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000030 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 190
# [LightGBM] [Info] Number of data points in the train set: 532, number of used features: 3
# [LightGBM] [Info] Start training from score 0.258907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
for key, result in results.items():
    y_true = result['y_true'].flatten()
    y_pred = result['y_pred'].flatten()
    df_original = result["df_original"]

    print(f"\n--- Visualizing Best Model: {key} ---")
    print(f"  -> MAE of Model: {result["mae"]:.4f}")
    print(f"  -> MSE of Model: {result["mse"]:.6f}")
    print(f"  -> R2 of Model: {result["r2"]:.6f}")

    predict_and_plot(key, results, provider, False)
# Out:
# --- Visualizing Best Model: 1A - 3A ---
#   -> MAE of Model: 0.2766
#   -> MSE of Model: 0.150784
#   -> R2 of Model: 0.579368
#
# --- Metrics vs. Smoothed Baseline for '1A - 3A' ---
#   Smoothed MAE: 0.1072 V
#   Smoothed MSE: 0.0270
#   Smoothed R²:  0.7515
# -------------------------------------------------
# c:\Users\dimaherez\StudioProjects\battery-model-ann\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# --- Visualizing Best Model: 9A - 11A ---
#   -> MAE of Model: 0.1160
#   -> MSE of Model: 0.047288
#   -> R2 of Model: 0.758717
#
# --- Metrics vs. Smoothed Baseline for '9A - 11A' ---
#   Smoothed MAE: 0.0526 V
#   Smoothed MSE: 0.0069
#   Smoothed R²:  0.9612
# -------------------------------------------------
# ...
